# %%
# !pip --version
# Out:
# pip 21.1.1 from /opt/conda/lib/python3.8/site-packages/pip (python 3.8)

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /opt/conda/lib/python3.8/site-packages (21.1.1)
# Collecting pip
#   Downloading pip-22.3.1-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 6.8 MB/s eta 0:00:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.1.1
#     Uninstalling pip-21.1.1:
#       Successfully uninstalled pip-21.1.1
# Successfully installed pip-22.3.1

# %%
# !pip install -r requirements.txt

# %%
import os
import pprint
import tempfile

import absl
import tensorflow as tf
from tfx import v1 as tfx
import tfx.dsl as dsl
from tfx.orchestration.experimental.interactive.interactive_context import InteractiveContext
from tfx.examples.custom_components.presto_example_gen.proto import presto_config_pb2
from tfx.examples.custom_components.presto_example_gen.presto_component.component import PrestoExampleGen

from tfx.components.example_gen.component import FileBasedExampleGen
from tfx.components.example_gen.custom_executors import parquet_executor
from tfx.proto import example_gen_pb2, transform_pb2, trainer_pb2
from tfx.dsl.components.base import executor_spec
import tensorflow_model_analysis as tfma


tf.get_logger().propagate = False
pp = pprint.PrettyPrinter()

# %%
# Set up logging.
absl.logging.set_verbosity(absl.logging.ERROR)

print('TensorFlow version: {}'.format(tf.__version__))
print('TFX version: {}'.format(tfx.__version__))
# Out:
# TensorFlow version: 2.5.3
# TFX version: 1.2.0

# %%
BUCKET_NAME = "ml-data"
PIPELINE_NAME = 'fraud_detection_tfx_pipeline'
PIPELINE_ROOT = f"s3://{BUCKET_NAME}/{PIPELINE_NAME}"
METADATA_PATH = os.path.join('.', f"resources/{PIPELINE_NAME}/tfx_metadata", 'metadata.db')

SRC_FOLDER = f"s3://{BUCKET_NAME}/tb_fraud"

# %%
_parallelism=1
_beam_pipeline_args_by_runner = {
    'DirectRunner': [
        '--direct_running_mode=multi_threading',
        '--direct_num_workers=%d' % _parallelism,
        "--s3_endpoint_url=http://storage:9000/",
        "--s3_access_key_id=minioadmin",
        "--s3_secret_access_key=minioadmin",
        "--s3_disable_ssl",
        "--s3_verify=False"
    ],
    'SparkRunner': [
        '--runner=PortableRunner',
        '--job_endpoint=localhost:8099',
        '--environment_type=DOCKER',
        '--environment_config=apache/beam_python3.6_sdk:2.29.0-custom',
        '--cache_disabled',
        '--spark_submit_uber_jar',
        '--sdk_worker_parallelism=1',
        "--s3_endpoint_url=http://172.17.0.1:9000/",
        "--s3_access_key_id=minioadmin",
        "--s3_secret_access_key=minioadmin",
        "--s3_disable_ssl",
        "--s3_verify=False"
    ],
    'SparkDirectRunner': [
        '--runner=SparkRunner',
        '--spark_submit_uber_jar',
        '--spark_master_url=spark://localhost:7077 ',
        '--spark_rest_url=http://localhost:6066',
        '--environment_type=DOCKER',
        '--environment_config=apachebeam/python3.6_sdk',
        '--cache_disabled',
        '--sdk_worker_parallelism=1'
    ]
}

# %%
_beam_pipeline_args = _beam_pipeline_args_by_runner["DirectRunner"]
context = InteractiveContext(pipeline_name=PIPELINE_NAME,
                             pipeline_root=PIPELINE_ROOT,
                             metadata_connection_config=tfx.orchestration.metadata.sqlite_metadata_connection_config(METADATA_PATH),
                             beam_pipeline_args=_beam_pipeline_args
                            )

# %%
# FileBasedExampleGen
# input_config = example_gen_pb2.Input(splits=[example_gen_pb2.Input.Split(name="source", pattern="*.snappy.parquet")])
# example_component = FileBasedExampleGen(input_base=SRC_FOLDER,
#                                         input_config=input_config,
#                                         custom_executor_spec=executor_spec.BeamExecutorSpec(parquet_executor.Executor))

# PrestoBasedExampleGen
_presto_config = presto_config_pb2.PrestoConnConfig(host="trino-coordinator",port=8080, user="admin")
_query = 'SELECT * FROM hive.ml_fraud_detection_db.tb_fraud'
example_component = PrestoExampleGen(_presto_config, query=_query)
context.run(example_component)

# %%
stats_component = tfx.components.StatisticsGen(examples=example_component.outputs['examples'])
stats_component_response = context.run(stats_component)

# %%
context.show(stats_component.outputs['statistics'])

# %%
infer_schema_component = tfx.components.SchemaGen(statistics=stats_component.outputs["statistics"])
schema_component_response = context.run(infer_schema_component)

# %%
context.show(infer_schema_component.outputs['schema'])
# Out:
# <b>Artifact at s3://ml-data/fraud_detection_tfx_pipeline/SchemaGen/schema/3</b><br/><br/>
#                     Type  Presence Valency           Domain
# Feature name
# 'card4'           STRING  optional  single          'card4'
# 'card6'           STRING  optional  single          'card6'
# 'm2'              STRING  optional  single             'm2'
# 'm3'              STRING  optional  single             'm3'
# 'm4'              STRING  optional  single             'm4'
# 'm5'              STRING  optional  single             'm5'
# 'm6'              STRING  optional  single             'm6'
# 'm7'              STRING  optional  single             'm7'
# 'm8'              STRING  optional  single             'm8'
# 'm9'              STRING  optional  single             'm9'
# 'p_emaildomain'   STRING  optional  single  'p_emaildomain'
# 'productcd'       STRING  optional  single      'productcd'
# 'r_emaildomain'   STRING  optional  single  'r_emaildomain'
# 'c1'               FLOAT  optional  single                -
# 'c13'              FLOAT  optional  single                -
# 'c5'               FLOAT  optional  single                -
# 'card1'            FLOAT  optional  single                -
# 'card2'            FLOAT  optional  single                -
# 'card3'            FLOAT  optional  single                -
# 'card5'            FLOAT  optional  single                -
# 'd1'               FLOAT  optional  single                -
# 'd10'              FLOAT  optional  single                -
# 'd11'              FLOAT  optional  single                -
# 'd15'              FLOAT  optional  single                -
# 'd3'               FLOAT  optional  single                -
# 'd4'               FLOAT  optional  single                -
# 'd5'               FLOAT  optional  single                -
# 'dist1'            FLOAT  optional  single                -
# 'isfraud'            INT  optional  single                -
# 'transactionamt'   FLOAT  optional  single                -
# 'v10'              FLOAT  optional  single                -
# 'v12'              FLOAT  optional  single                -
# 'v15'              FLOAT  optional  single                -
# 'v19'              FLOAT  optional  single                -
# 'v2'               FLOAT  optional  single                -
# 'v22'              FLOAT  optional  single                -
# 'v23'              FLOAT  optional  single                -
# 'v25'              FLOAT  optional  single                -
# 'v29'              FLOAT  optional  single                -
# 'v3'               FLOAT  optional  single                -
# 'v35'              FLOAT  optional  single                -
# 'v4'               FLOAT  optional  single                -
# 'v6'               FLOAT  optional  single                -
# 'v8'               FLOAT  optional  single                -
# /opt/conda/lib/python3.8/site-packages/tensorflow_data_validation/utils/display_util.py:180: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('max_colwidth', -1)
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Values
# Domain
# 'card4'          'american express', 'discover', 'mastercard', 'visa'
# 'card6'          'charge card', 'credit', 'debit', 'debit or credit'
# 'm2'             'F', 'T'
# 'm3'             'F', 'T'
# 'm4'             'M0', 'M1', 'M2'
# 'm5'             'F', 'T'
# 'm6'             'F', 'T'
# 'm7'             'F', 'T'
# 'm8'             'F', 'T'
# 'm9'             'F', 'T'
# 'p_emaildomain'  'aim.com', 'anonymous.com', 'aol.com', 'att.net', 'bellsouth.net', 'cableone.net', 'centurylink.net', 'cfl.rr.com', 'charter.net', 'comcast.net', 'cox.net', 'earthlink.net', 'embarqmail.com', 'frontier.com', 'frontiernet.net', 'gmail', 'gmail.com', 'gmx.de', 'hotmail.co.uk', 'hotmail.com', 'hotmail.de', 'hotmail.es', 'hotmail.fr', 'icloud.com', 'juno.com', 'live.com', 'live.com.mx', 'live.fr', 'mac.com', 'mail.com', 'me.com', 'msn.com', 'netzero.com', 'netzero.net', 'optonline.net', 'outlook.com', 'outlook.es', 'prodigy.net.mx', 'protonmail.com', 'ptd.net', 'q.com', 'roadrunner.com', 'rocketmail.com', 'sbcglobal.net', 'sc.rr.com', 'servicios-ta.com', 'suddenlink.net', 'twc.com', 'verizon.net', 'web.de', 'windstream.net', 'yahoo.co.jp', 'yahoo.co.uk', 'yahoo.com', 'yahoo.com.mx', 'yahoo.de', 'yahoo.es', 'yahoo.fr', 'ymail.com'
# 'productcd'      'C', 'H', 'R', 'S', 'W'
# 'r_emaildomain'  'aim.com', 'anonymous.com', 'aol.com', 'att.net', 'bellsouth.net', 'cableone.net', 'centurylink.net', 'cfl.rr.com', 'charter.net', 'comcast.net', 'cox.net', 'earthlink.net', 'embarqmail.com', 'frontier.com', 'frontiernet.net', 'gmail', 'gmail.com', 'gmx.de', 'hotmail.co.uk', 'hotmail.com', 'hotmail.de', 'hotmail.es', 'hotmail.fr', 'icloud.com', 'juno.com', 'live.com', 'live.com.mx', 'live.fr', 'mac.com', 'mail.com', 'me.com', 'msn.com', 'netzero.com', 'netzero.net', 'optonline.net', 'outlook.com', 'outlook.es', 'prodigy.net.mx', 'protonmail.com', 'ptd.net', 'q.com', 'roadrunner.com', 'rocketmail.com', 'sbcglobal.net', 'sc.rr.com', 'scranton.edu', 'servicios-ta.com', 'suddenlink.net', 'twc.com', 'verizon.net', 'web.de', 'windstream.net', 'yahoo.co.jp', 'yahoo.co.uk', 'yahoo.com', 'yahoo.com.mx', 'yahoo.de', 'yahoo.es', 'yahoo.fr', 'ymail.com'

# %%
transform_component = tfx.components.Transform(examples=example_component.outputs["examples"],
                                                   schema=infer_schema_component.outputs["schema"],
                                                   module_file="python_modules/standardscalar_preprocessor.py")
trainer_component_response = context.run(transform_component)
# Out:
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# WARNING:tensorflow:From /opt/conda/lib/python3.8/site-packages/tensorflow_transform/tf_utils.py:261: Tensor.experimental_ref (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use ref() instead.
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType]] instead.
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# WARNING:root:This output type hint will be ignored and not used for type-checking purposes. Typically, output type hints for a PTransform are single (or nested) types wrapped by a PCollection, PDone, or None. Got: Tuple[Dict[str, Union[NoneType, _Dataset]], Union[Dict[str, Dict[str, PCollection]], NoneType]] instead.
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# INFO:tensorflow:Assets written to: s3://ml-data/fraud_detection_tfx_pipeline/Transform/transform_graph/4/.temp_path/tftransform_tmp/ad8b073fd0534a61af50706b789c928e/assets
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# ...
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# INFO:tensorflow:Assets written to: s3://ml-data/fraud_detection_tfx_pipeline/Transform/transform_graph/4/.temp_path/tftransform_tmp/98564b4dda1a46b89dabb6f8ecb8c1d0/assets
# ***********************************************************
# key => card4
# output = Tensor("compute_and_apply_vocabulary_4/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => card6
# output = Tensor("compute_and_apply_vocabulary/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m2
# output = Tensor("compute_and_apply_vocabulary_1/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m3
# output = Tensor("compute_and_apply_vocabulary_12/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m4
# output = Tensor("compute_and_apply_vocabulary_2/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m5
# output = Tensor("compute_and_apply_vocabulary_10/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m6
# output = Tensor("compute_and_apply_vocabulary_6/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m7
# output = Tensor("compute_and_apply_vocabulary_5/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m8
# output = Tensor("compute_and_apply_vocabulary_3/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => m9
# output = Tensor("compute_and_apply_vocabulary_9/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => p_emaildomain
# output = Tensor("compute_and_apply_vocabulary_7/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => productcd
# output = Tensor("compute_and_apply_vocabulary_11/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => r_emaildomain
# output = Tensor("compute_and_apply_vocabulary_8/apply_vocab/None_Lookup/SelectV2:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => c1
# output = Tensor("scale_to_0_1_19/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c13
# output = Tensor("scale_to_0_1_29/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => c5
# output = Tensor("scale_to_0_1_11/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card1
# output = Tensor("scale_to_0_1_28/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card2
# output = Tensor("scale_to_0_1_17/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card3
# output = Tensor("scale_to_0_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => card5
# output = Tensor("scale_to_0_1_7/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d1
# output = Tensor("scale_to_0_1_25/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d10
# output = Tensor("scale_to_0_1_4/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d11
# output = Tensor("scale_to_0_1_5/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d15
# output = Tensor("scale_to_0_1_9/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d3
# output = Tensor("scale_to_0_1_27/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d4
# output = Tensor("scale_to_0_1_1/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => d5
# output = Tensor("scale_to_0_1_10/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => dist1
# output = Tensor("scale_to_0_1_26/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => isfraud
# output = Tensor("isfraud_to_dense:0", shape=(None, 1), dtype=int64)
# input = (None, None)
#
#
#
# key => transactionamt
# output = Tensor("scale_to_0_1_8/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v10
# output = Tensor("scale_to_0_1_16/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v12
# output = Tensor("scale_to_0_1_22/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v15
# output = Tensor("scale_to_0_1_18/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v19
# output = Tensor("scale_to_0_1_12/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v2
# output = Tensor("scale_to_0_1_20/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v22
# output = Tensor("scale_to_0_1_21/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v23
# output = Tensor("scale_to_0_1_24/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v25
# output = Tensor("scale_to_0_1_13/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v29
# output = Tensor("scale_to_0_1_2/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v3
# output = Tensor("scale_to_0_1_14/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v35
# output = Tensor("scale_to_0_1_6/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v4
# output = Tensor("scale_to_0_1_15/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v6
# output = Tensor("scale_to_0_1_3/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# key => v8
# output = Tensor("scale_to_0_1_23/add_1:0", shape=(None, 1), dtype=float32)
# input = (None, None)
#
#
#
# ***********************************************************
# ExecutionResult(
#     component_id: Transform
#     execution_id: 4
#     outputs:
#         transform_graph: Channel(
#             type_name: TransformGraph
#             artifacts: [Artifact(artifact: id: 4
#         type_id: 20
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/transform_graph/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "transform_graph"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 20
#         name: "TransformGraph"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         transformed_examples: Channel(
#             type_name: Examples
#             artifacts: [Artifact(artifact: id: 5
#         type_id: 14
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/transformed_examples/4"
#         properties {
#           key: "split_names"
#           value {
#             string_value: "[\"train\", \"eval\"]"
#           }
#         }
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "transformed_examples"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 14
#         name: "Examples"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         properties {
#           key: "version"
#           value: INT
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         updated_analyzer_cache: Channel(
#             type_name: TransformCache
#             artifacts: [Artifact(artifact: id: 6
#         type_id: 21
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/updated_analyzer_cache/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "updated_analyzer_cache"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 21
#         name: "TransformCache"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         pre_transform_schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 7
#         type_id: 18
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/pre_transform_schema/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pre_transform_schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         pre_transform_stats: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 8
#         type_id: 16
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/pre_transform_stats/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "pre_transform_stats"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_schema: Channel(
#             type_name: Schema
#             artifacts: [Artifact(artifact: id: 9
#         type_id: 18
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/post_transform_schema/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_schema"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 18
#         name: "Schema"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_stats: Channel(
#             type_name: ExampleStatistics
#             artifacts: [Artifact(artifact: id: 10
#         type_id: 16
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/post_transform_stats/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_stats"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 16
#         name: "ExampleStatistics"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         post_transform_anomalies: Channel(
#             type_name: ExampleAnomalies
#             artifacts: [Artifact(artifact: id: 11
#         type_id: 22
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Transform/post_transform_anomalies/4"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "post_transform_anomalies"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Transform"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 22
#         name: "ExampleAnomalies"
#         properties {
#           key: "span"
#           value: INT
#         }
#         properties {
#           key: "split_names"
#           value: STRING
#         }
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
context.show(transform_component.outputs['transformed_examples'])
# Out:
# <b>Artifact at s3://ml-data/fraud_detection_tfx_pipeline/Transform/transformed_examples/40</b><br/><br/>

# %%
trainer_component = tfx.components.Trainer(module_file='python_modules/trainer_module.py',
                                               examples=transform_component.outputs['transformed_examples'],
                                               transform_graph=transform_component.outputs['transform_graph'],
                                               schema=infer_schema_component.outputs['schema'],
                                               train_args=trainer_pb2.TrainArgs(num_steps=10),
                                               eval_args=trainer_pb2.EvalArgs(num_steps=5),
                                               custom_config= {
                                                   "epochs": 13
                                               }
                                          )
trainer_component_response = context.run(trainer_component, enable_cache=False)
# Out:
# fn_args = FnArgs(working_dir=None, train_files=['s3://ml-data/fraud_detection_tfx_pipeline/Transform/transformed_examples/4/Split-train/*'], eval_files=['s3://ml-data/fraud_detection_tfx_pipeline/Transform/transformed_examples/4/Split-eval/*'], train_steps=10, eval_steps=5, schema_path='s3://ml-data/fraud_detection_tfx_pipeline/SchemaGen/schema/3/schema.pbtxt', schema_file='s3://ml-data/fraud_detection_tfx_pipeline/SchemaGen/schema/3/schema.pbtxt', transform_graph_path='s3://ml-data/fraud_detection_tfx_pipeline/Transform/transform_graph/4', transform_output='s3://ml-data/fraud_detection_tfx_pipeline/Transform/transform_graph/4', data_accessor=DataAccessor(tf_dataset_factory=<function get_tf_dataset_factory_from_artifact.<locals>.dataset_factory at 0x7f02563caaf0>, record_batch_factory=<function get_record_batch_factory_from_artifact.<locals>.record_batch_factory at 0x7f01339a0b80>, data_view_decode_fn=None), serving_model_dir='s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model/5/Format-Serving', eval_model_dir='s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model/5/Format-TFMA', model_run_dir='s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model_run/5', base_model=None, hyperparameters=None, custom_config={'epochs': 13})
# features = ['c1', 'c13', 'c5', 'card1', 'card2', 'card3', 'card4', 'card5', 'card6', 'd1', 'd10', 'd11', 'd15', 'd3', 'd4', 'd5', 'dist1', 'm2', 'm3', 'm4', 'm5', 'm6', 'm7', 'm8', 'm9', 'p_emaildomain', 'productcd', 'r_emaildomain', 'transactionamt', 'v10', 'v12', 'v15', 'v19', 'v2', 'v22', 'v23', 'v25', 'v29', 'v3', 'v35', 'v4', 'v6', 'v8']
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# c1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# c13 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# c5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# card1 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# card2 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# card3 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# card4 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# card5 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# card6 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# d1 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# d10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# d11 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# d15 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# d3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# d4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# d5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# dist1 (InputLayer)              [(None, 1)]          0
# __________________________________________________________________________________________________
# m2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m5 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m7 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# m9 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# p_emaildomain (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# productcd (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# r_emaildomain (InputLayer)      [(None, 1)]          0
# __________________________________________________________________________________________________
# transactionamt (InputLayer)     [(None, 1)]          0
# __________________________________________________________________________________________________
# v10 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v12 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v15 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v19 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v2 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# v22 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v23 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v25 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v29 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v3 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# v35 (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# v4 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# v6 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# v8 (InputLayer)                 [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 43)           0           c1[0][0]
#                                                                  c13[0][0]
#                                                                  c5[0][0]
#                                                                  card1[0][0]
#                                                                  card2[0][0]
#                                                                  card3[0][0]
#                                                                  card4[0][0]
#                                                                  card5[0][0]
#                                                                  card6[0][0]
#                                                                  d1[0][0]
#                                                                  d10[0][0]
#                                                                  d11[0][0]
#                                                                  d15[0][0]
#                                                                  d3[0][0]
#                                                                  d4[0][0]
#                                                                  d5[0][0]
#                                                                  dist1[0][0]
#                                                                  m2[0][0]
#                                                                  m3[0][0]
#                                                                  m4[0][0]
#                                                                  m5[0][0]
#                                                                  m6[0][0]
#                                                                  m7[0][0]
#                                                                  m8[0][0]
#                                                                  m9[0][0]
#                                                                  p_emaildomain[0][0]
#                                                                  productcd[0][0]
#                                                                  r_emaildomain[0][0]
#                                                                  transactionamt[0][0]
#                                                                  v10[0][0]
#                                                                  v12[0][0]
#                                                                  v15[0][0]
#                                                                  v19[0][0]
#                                                                  v2[0][0]
#                                                                  v22[0][0]
#                                                                  v23[0][0]
#                                                                  v25[0][0]
#                                                                  v29[0][0]
#                                                                  v3[0][0]
#                                                                  v35[0][0]
#                                                                  v4[0][0]
#                                                                  v6[0][0]
#                                                                  v8[0][0]
# __________________________________________________________________________________________________
# dense_layer_1 (Dense)           (None, 256)          11264       concatenate[0][0]
# __________________________________________________________________________________________________
# dense_later_2 (Dense)           (None, 256)          65792       dense_layer_1[0][0]
# __________________________________________________________________________________________________
# dense_layer_3 (Dense)           (None, 256)          65792       dense_later_2[0][0]
# __________________________________________________________________________________________________
# dense_later_4 (Dense)           (None, 256)          65792       dense_layer_3[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 256)          0           dense_later_4[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            257         dropout[0][0]
# ==================================================================================================
# Total params: 208,897
# Trainable params: 208,897
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/13
# 10/10 [==============================] - ETA: 4s - loss: 0.7411 - auc: 0.535 - 1s 34ms/step - loss: 0.3192 - auc: 0.4666 - val_loss: 0.1482 - val_auc: 0.5188
# Epoch 2/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1052 - auc: 0.510 - 0s 16ms/step - loss: 0.1238 - auc: 0.6550 - val_loss: 0.1254 - val_auc: 0.6200
# Epoch 3/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1291 - auc: 0.683 - 0s 17ms/step - loss: 0.1712 - auc: 0.6564 - val_loss: 0.1266 - val_auc: 0.7034
# Epoch 4/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1470 - auc: 0.794 - 0s 16ms/step - loss: 0.1260 - auc: 0.6630 - val_loss: 0.1312 - val_auc: 0.6849
# Epoch 5/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1539 - auc: 0.734 - 0s 18ms/step - loss: 0.1531 - auc: 0.6454 - val_loss: 0.1086 - val_auc: 0.7106
# Epoch 6/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1001 - auc: 0.915 - 0s 17ms/step - loss: 0.1207 - auc: 0.7320 - val_loss: 0.1249 - val_auc: 0.7055
# Epoch 7/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1236 - auc: 0.788 - 0s 18ms/step - loss: 0.0930 - auc: 0.7733 - val_loss: 0.1249 - val_auc: 0.7306
# Epoch 8/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1765 - auc: 0.648 - 0s 17ms/step - loss: 0.1349 - auc: 0.7376 - val_loss: 0.1338 - val_auc: 0.7121
# Epoch 9/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1091 - auc: 0.922 - 0s 16ms/step - loss: 0.1083 - auc: 0.7131 - val_loss: 0.1133 - val_auc: 0.7662
# Epoch 10/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1159 - auc: 0.833 - 0s 18ms/step - loss: 0.0897 - auc: 0.8534 - val_loss: 0.1211 - val_auc: 0.7661
# Epoch 11/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1618 - auc: 0.774 - 0s 17ms/step - loss: 0.1169 - auc: 0.7632 - val_loss: 0.1064 - val_auc: 0.7454
# Epoch 12/13
# 10/10 [==============================] - ETA: 0s - loss: 0.1542 - auc: 0.699 - 0s 17ms/step - loss: 0.1074 - auc: 0.8056 - val_loss: 0.1250 - val_auc: 0.6875
# Epoch 13/13
# 10/10 [==============================] - ETA: 0s - loss: 0.0807 - auc: 0.869 - 0s 18ms/step - loss: 0.0989 - auc: 0.8390 - val_loss: 0.1235 - val_auc: 0.6783
# tf_transform_output.raw_feature_spec() {'card4': VarLenFeature(dtype=tf.string), 'card6': VarLenFeature(dtype=tf.string), 'm2': VarLenFeature(dtype=tf.string), 'm3': VarLenFeature(dtype=tf.string), 'm4': VarLenFeature(dtype=tf.string), 'm5': VarLenFeature(dtype=tf.string), 'm6': VarLenFeature(dtype=tf.string), 'm7': VarLenFeature(dtype=tf.string), 'm8': VarLenFeature(dtype=tf.string), 'm9': VarLenFeature(dtype=tf.string), 'p_emaildomain': VarLenFeature(dtype=tf.string), 'productcd': VarLenFeature(dtype=tf.string), 'r_emaildomain': VarLenFeature(dtype=tf.string), 'c1': VarLenFeature(dtype=tf.float32), 'c13': VarLenFeature(dtype=tf.float32), 'c5': VarLenFeature(dtype=tf.float32), 'card1': VarLenFeature(dtype=tf.float32), 'card2': VarLenFeature(dtype=tf.float32), 'card3': VarLenFeature(dtype=tf.float32), 'card5': VarLenFeature(dtype=tf.float32), 'd1': VarLenFeature(dtype=tf.float32), 'd10': VarLenFeature(dtype=tf.float32), 'd11': VarLenFeature(dtype=tf.float32), 'd15': VarLenFeature(dtype=tf.float32), 'd3': VarLenFeature(dtype=tf.float32), 'd4': VarLenFeature(dtype=tf.float32), 'd5': VarLenFeature(dtype=tf.float32), 'dist1': VarLenFeature(dtype=tf.float32), 'isfraud': VarLenFeature(dtype=tf.int64), 'transactionamt': VarLenFeature(dtype=tf.float32), 'v10': VarLenFeature(dtype=tf.float32), 'v12': VarLenFeature(dtype=tf.float32), 'v15': VarLenFeature(dtype=tf.float32), 'v19': VarLenFeature(dtype=tf.float32), 'v2': VarLenFeature(dtype=tf.float32), 'v22': VarLenFeature(dtype=tf.float32), 'v23': VarLenFeature(dtype=tf.float32), 'v25': VarLenFeature(dtype=tf.float32), 'v29': VarLenFeature(dtype=tf.float32), 'v3': VarLenFeature(dtype=tf.float32), 'v35': VarLenFeature(dtype=tf.float32), 'v4': VarLenFeature(dtype=tf.float32), 'v6': VarLenFeature(dtype=tf.float32), 'v8': VarLenFeature(dtype=tf.float32)}
# K => card4 f => VarLenFeature(dtype=tf.string)
# K => card6 f => VarLenFeature(dtype=tf.string)
# K => m2 f => VarLenFeature(dtype=tf.string)
# K => m3 f => VarLenFeature(dtype=tf.string)
# K => m4 f => VarLenFeature(dtype=tf.string)
# K => m5 f => VarLenFeature(dtype=tf.string)
# K => m6 f => VarLenFeature(dtype=tf.string)
# K => m7 f => VarLenFeature(dtype=tf.string)
# K => m8 f => VarLenFeature(dtype=tf.string)
# K => m9 f => VarLenFeature(dtype=tf.string)
# K => p_emaildomain f => VarLenFeature(dtype=tf.string)
# K => productcd f => VarLenFeature(dtype=tf.string)
# K => r_emaildomain f => VarLenFeature(dtype=tf.string)
# K => c1 f => VarLenFeature(dtype=tf.float32)
# K => c13 f => VarLenFeature(dtype=tf.float32)
# K => c5 f => VarLenFeature(dtype=tf.float32)
# K => card1 f => VarLenFeature(dtype=tf.float32)
# K => card2 f => VarLenFeature(dtype=tf.float32)
# K => card3 f => VarLenFeature(dtype=tf.float32)
# K => card5 f => VarLenFeature(dtype=tf.float32)
# K => d1 f => VarLenFeature(dtype=tf.float32)
# K => d10 f => VarLenFeature(dtype=tf.float32)
# K => d11 f => VarLenFeature(dtype=tf.float32)
# K => d15 f => VarLenFeature(dtype=tf.float32)
# K => d3 f => VarLenFeature(dtype=tf.float32)
# K => d4 f => VarLenFeature(dtype=tf.float32)
# K => d5 f => VarLenFeature(dtype=tf.float32)
# K => dist1 f => VarLenFeature(dtype=tf.float32)
# K => transactionamt f => VarLenFeature(dtype=tf.float32)
# K => v10 f => VarLenFeature(dtype=tf.float32)
# K => v12 f => VarLenFeature(dtype=tf.float32)
# K => v15 f => VarLenFeature(dtype=tf.float32)
# K => v19 f => VarLenFeature(dtype=tf.float32)
# K => v2 f => VarLenFeature(dtype=tf.float32)
# K => v22 f => VarLenFeature(dtype=tf.float32)
# K => v23 f => VarLenFeature(dtype=tf.float32)
# K => v25 f => VarLenFeature(dtype=tf.float32)
# K => v29 f => VarLenFeature(dtype=tf.float32)
# K => v3 f => VarLenFeature(dtype=tf.float32)
# K => v35 f => VarLenFeature(dtype=tf.float32)
# K => v4 f => VarLenFeature(dtype=tf.float32)
# K => v6 f => VarLenFeature(dtype=tf.float32)
# K => v8 f => VarLenFeature(dtype=tf.float32)
# [TensorSpec(shape=<unknown>, dtype=tf.string, name='card4'), TensorSpec(shape=<unknown>, dtype=tf.string, name='card6'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m2'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m3'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m4'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m5'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m6'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m7'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m8'), TensorSpec(shape=<unknown>, dtype=tf.string, name='m9'), TensorSpec(shape=<unknown>, dtype=tf.string, name='p_emaildomain'), TensorSpec(shape=<unknown>, dtype=tf.string, name='productcd'), TensorSpec(shape=<unknown>, dtype=tf.string, name='r_emaildomain'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='c1'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='c13'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='c5'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='card1'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='card2'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='card3'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='card5'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d1'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d10'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d11'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d15'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d3'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d4'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='d5'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='dist1'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='transactionamt'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v10'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v12'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v15'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v19'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v2'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v22'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v23'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v25'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v29'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v3'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v35'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v4'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v6'), TensorSpec(shape=<unknown>, dtype=tf.float32, name='v8')]
# INFO:tensorflow:Assets written to: s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model/5/Format-Serving/assets
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 5
#     outputs:
#         model: Channel(
#             type_name: Model
#             artifacts: [Artifact(artifact: id: 12
#         type_id: 24
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 24
#         name: "Model"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         )
#         model_run: Channel(
#             type_name: ModelRun
#             artifacts: [Artifact(artifact: id: 13
#         type_id: 25
#         uri: "s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model_run/5"
#         custom_properties {
#           key: "name"
#           value {
#             string_value: "model_run"
#           }
#         }
#         custom_properties {
#           key: "producer_component"
#           value {
#             string_value: "Trainer"
#           }
#         }
#         custom_properties {
#           key: "state"
#           value {
#             string_value: "published"
#           }
#         }
#         custom_properties {
#           key: "tfx_version"
#           value {
#             string_value: "1.2.0"
#           }
#         }
#         state: LIVE
#         , artifact_type: id: 25
#         name: "ModelRun"
#         )]
#             additional_properties: {}
#             additional_custom_properties: {}
#         ))

# %%
# push_uri = pusher_component.outputs['pushed_model'].get()[0].uri
push_uri = f"{trainer_component.outputs['model'].get()[0].uri}/Format-Serving"
print(push_uri)
# Out:
# s3://ml-data/fraud_detection_tfx_pipeline/Trainer/model/65/Format-Serving
